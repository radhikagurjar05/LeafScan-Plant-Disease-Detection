# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = "../dataset/leaf_dataset"

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="training"
)

val_data = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="validation"
)

model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_data, validation_data=val_data, epochs=5)


model.save("../backend/leaf_classifier.h5")

print(" leaf_classifier.h5 created!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 train_dir = "../dataset/leaf_dataset"
#       7 datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
# ----> 9 train_data = datagen.flow_from_directory(
#      10     train_dir,
#      11     target_size=(224, 224),
#      12     batch_size=32,
#      13     class_mode="binary",
#      14     subset="training"
#      15 )
#      17 val_data = datagen.flow_from_directory(
#      18     train_dir,
#      19     target_size=(224, 224),
#    (...)     22     subset="validation"
#      23 )
#      25 model = models.Sequential([
#      26     layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
#      27     layers.MaxPooling2D(),
#    (...)     32     layers.Dense(1, activation='sigmoid')
#      33 ])
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)   1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
#    1140         color_mode=color_mode,
#    1141         keep_aspect_ratio=keep_aspect_ratio,
#    1142         classes=classes,
#    1143         class_mode=class_mode,
#    1144         data_format=self.data_format,
#    1145         batch_size=batch_size,
#    1146         shuffle=shuffle,
#    1147         seed=seed,
#    1148         save_to_dir=save_to_dir,
#    1149         save_prefix=save_prefix,
#    1150         save_format=save_format,
#    1151         follow_links=follow_links,
#    1152         subset=subset,
#    1153         interpolation=interpolation,
#    1154         dtype=self.dtype,
#    1155     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\preprocessing\image.py:456, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454 if not classes:
#     455     classes = []
# --> 456     for subdir in sorted(os.listdir(directory)):
#     457         if os.path.isdir(os.path.join(directory, subdir)):
#     458             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../dataset/leaf_dataset'
